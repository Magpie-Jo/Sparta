# %%
# import usage libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime, timedelta
import platform
import geopandas as gpd
import folium
import warnings
from IPython.display import IFrame
from folium.plugins import MarkerCluster
from folium.features import DivIcon
from shapely.affinity import translate 

print(platform.system())
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 50)

# 시각화 OS별 한글폰트 설정
if platform.system() == 'Windows':
    plt.rcParams['font.family'] = 'Malgun Gothic'  # Windows 폰트 설정
elif platform.system() == 'Mac':
    plt.rcParams['font.family'] = 'AppleGothic'  # Mac 폰트 설정
elif platform.system() == 'Linux':
    plt.rcParams['font.family'] = 'NanumGothic' # Linux 폰트 설정(코랩용)
# Out:
# Windows

# %%
# 정제 데이터 CSV 저장  및 불러오기
if platform.system() == 'Windows':
    airbnb = pd.read_csv('Airbnb_cleansed.csv') # 로컬용 접근경로(동일폴더)
    geo_ny = gpd.read_file('yn_geo_map.geojson')

elif platform.system() == 'Mac':
    airbnb = pd.read_csv('Airbnb_cleansed.csv') # 로컬용 접근경로(동일폴더)
    geo_ny = gpd.read_file('yn_geo_map.geojson')

elif platform.system() == 'Linux':
    airbnb = pd.read_csv('/content/drive /MyDrive/심화프로젝트/data/Airbnb_cleansed.csv') #코랩 공유용 경로(My Drive에 공유폴더 바로가기 추가 필요)
    geo_ny = gpd.read_file('/content/drive/MyDrive/심화프로젝트/data/yn_geo_map.geojson')

# %%
# 지역별 그룹화
local = airbnb.groupby('neighbourhood_group_cleansed')

# 지역별 데이터프레임 분리        
brooklyn = local.get_group('Brooklyn')
manhattan = local.get_group('Manhattan')
queens = local.get_group('Queens')

# %%
brooklyn_by_property = brooklyn.groupby('property_group')
manhattan_by_property = manhattan.groupby('property_group')
queens_by_property = queens.groupby('property_group')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 brooklyn_by_property = brooklyn.groupby('property_group')
#       2 manhattan_by_property = manhattan.groupby('property_group')
#       3 queens_by_property = queens.groupby('property_group')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\frame.py:9190, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9187 if level is None and by is None:
#    9188     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9190 return DataFrameGroupBy(
#    9191     obj=self,
#    9192     keys=by,
#    9193     axis=axis,
#    9194     level=level,
#    9195     as_index=as_index,
#    9196     sort=sort,
#    9197     group_keys=group_keys,
# ...
