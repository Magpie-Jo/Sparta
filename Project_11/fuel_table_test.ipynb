# %%
import pandas as pd

# %%
pd.read_csv('fuel_economy_km_per_l_E85.csv')
# Out:
#    year   make    model       class  engine_l  cylinders transmission  \
# 0  2000  ACURA    1.6EL     COMPACT       1.6          4           A4
# 1  2000  ACURA    1.6EL     COMPACT       1.6          4           M5
# 2  2000  ACURA    3.2TL    MID-SIZE       3.2          6          AS5
# 3  2000  ACURA    3.5RL    MID-SIZE       3.5          6           A4
# 4  2000  ACURA  INTEGRA  SUBCOMPACT       1.8          4           A4
#
#   fuel_code  city_l_per_100km  hwy_l_per_100km  comb_l_per_100km  \
# 0         X               9.2              6.7               8.1
# 1         X               8.5              6.5               7.6
# 2         Z              12.2              7.4              10.0
# 3         Z              13.4              9.2              11.5
# 4         X              10.0              7.0               8.6
#
#    comb_km_per_l  combined_mpg  emissions_g_per_km_original  co2_g_per_km_E85
# ...
